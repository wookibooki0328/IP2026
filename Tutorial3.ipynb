# %%
d = {'user':'bozo', 'pswd':1234}
print(d['user'])

d = {'user':'bozo', 'pswd':1234}
print(d['pswd'])

print(d['bozo'])
# Out:
# bozo
# 1234
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       4 d = {'user':'bozo', 'pswd':1234}
#       5 print(d['pswd'])
# ----> 7 print(d['bozo'])
#
# KeyError: 'bozo'

# %%
d = {'user':'bozo', 'pswd':1234}
d['user'] = 'clown'
print(d)
# Out:
# {'user': 'clown', 'pswd': 1234}

# %%
d = {'user':'bozo', 'pswd':1234}
d['id'] = 45
print(d)
# Out:
# {'user': 'bozo', 'pswd': 1234, 'id': 45}

# %%
d = {'user':'bozo', 'p':1234, 'i':34}
del d['user']
print(d)

d = {'user':'bozo', 'p':1234, 'i':34}
d.clear()
print(d)

d = {'user':'bozo', 'p':1234, 'i':34}
a=[1,2]
del a[1]
print(a)
# Out:
# {'p': 1234, 'i': 34}
# {}
# [1]

# %%
d = {'user':'bozo', 'p':1234, 'i':34}
d.keys()

d = {'user':'bozo', 'p':1234, 'i':34}
d.values()

d = {'user':'bozo', 'p':1234, 'i':34}
d.items()
# Out:
# dict_items([('user', 'bozo'), ('p', 1234), ('i', 34)])
