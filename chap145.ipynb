# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('j.png',0)
kernel = np.ones((5,5),np.uint8)
erosion1 = cv2.erode(img,kernel,iterations = 1)
erosion2 = cv2.erode(img,kernel,iterations = 2)
erosion3 = cv2.erode(img,kernel,iterations = 3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 3
#       1 img = cv2.imread('MAX.png',0)
#       2 kernel = np.ones((5,5),np.uint8)
# ----> 3 erosion1 = cv2.erode(img,kernel,iterations = 1)
#       4 erosion2 = cv2.erode(img,kernel,iterations = 2)
#       5 erosion3 = cv2.erode(img,kernel,iterations = 3)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\morph.dispatch.cpp:1054: error: (-215:Assertion failed) !src.empty() in function 'cv::erode'

# %%
cv2.imshow('img',img)
cv2.imshow('dst1',erosion1)
cv2.imshow('dst2',erosion2)
cv2.imshow('dst3',erosion3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = np.random.radiant(10, size(12,12))
