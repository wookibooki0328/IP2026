# %%
for someChar in '“Hello World':
    print (someChar)
# Out:
# “
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for x in range(5):
    print (x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for (x, y) in [('a',1), ('b',2), ('c',3), ('d',4)]:
    print (x)
# Out:
# a
# b
# c
# d

# %%
# Out:
# [6, 12, 14, 18]

# %%
# Out:
# [12, 10, 14, 8]
