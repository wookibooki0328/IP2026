# %%
li = [3, 6, 2, 7]
out = []
for elem in li:
    print (out)
    out.append(elem)
print(out)
# Out:
# []
# [3]
# [3, 6]
# [3, 6, 2]
# [3, 6, 2, 7]

# %%
[elem*2 for elem in li]
# Out:
# [6, 12, 4, 14]

# %%
li = [('a', 1), ('b', 2), ('c', 7)]
[ n * 3 for (x, n) in li]
# Out:
# [3, 6, 21]

# %%
li = [3, 6, 2, 7, 1, 9]
[elem * 2 for elem in li if elem > 2]
# Out:
# [6, 12, 14, 18]

# %%
li = [3, 2, 4, 1]
[elem*2 for elem in
    [item+3 for item in li] ]
