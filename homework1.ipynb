# %%
import numpy as np
import cv2

# %%
img = cv2.imread('MAX.jpg')
font = cv2.FONT_HERSHEY_SIMPLEX
drawing = False
img_copy = img.copy()
begin_x, begin_y = 0, 0 
end_x, end_y = 0, 0 
color_info = 'White' 
color = (255,255,255)

# %%
def change_color(key,info,a,b,c):
    global color, color_info, k
    if k == ord(key):
        color_info = info
        color = (a,b,c)
        
def draw_circle(event,x,y,flags, param):
    global begin_x, begin_y,end_x, end_y,drawing,img

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        img = img_copy.copy()
        begin_x, begin_y = x, y
        end_x, end_y = x, y
        
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            end_x, end_y = x, y

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False

# %%
def alpha_rectangle(begin_y,y,begin_x,x):
    global img, alpha
    y1, y2 = min(begin_y, y), max(begin_y, y) 
    x1, x2 = min(begin_x, x), max(begin_x, x)
    
    if y2 > y1 and x2 > x1:
        img = img_copy.copy()
        rectangle_img = img[y1:y2, x1:x2]
        rectangle_color = np.full(rectangle_img.shape, color, dtype=np.uint8)
        result = cv2.addWeighted(rectangle_color, alpha, rectangle_img, 1.0 - alpha, 0)
        img[y1:y2, x1:x2] = result
    return img

# %%
def nothing(x):
    pass

cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
cv2.createTrackbar('value','image',0,100,nothing)
cv2.setMouseCallback('image',draw_circle)
cv2.setTrackbarPos('value', 'image', 50)

while(1):
    val = cv2.getTrackbarPos('value','image')
    alpha = val / 100.0
    test = 'Mouse position ('+str(begin_x)+','+str(begin_y)+') ('+str(end_y)+','+str(end_x)+') - '+str(alpha)+' - '+str(color_info)
    cv2.putText(img,test ,(10,30), font, 1,(255,255,255),1,cv2.LINE_AA)
    cv2.imshow('image',img)

    alpha_rectangle(begin_y,end_y,begin_x,end_x)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
    change_color('k', 'Black', 0, 0, 0)
    change_color('b', 'Blue', 255, 0, 0)
    change_color('g', 'Green', 0, 255, 0)
    change_color('r', 'Red', 0, 0, 255)
    change_color('w', 'White', 255, 255, 255)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[31], line 10
#       7 cv2.setTrackbarPos('value', 'image', 50)
#       9 while(1):
# ---> 10     val = cv2.getTrackbarPos('value','image')
#      11     alpha = val / 100.0
#      12     test = 'Mouse position ('+str(begin_x)+','+str(begin_y)+') ('+str(end_y)+','+str(end_x)+') - '+str(alpha)+' - '+str(color_info)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2570: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'

# %%
https://youtu.be/z3z7iDN04b4


hm1 link
# Out:
#   Cell In[32], line 1
#     https://youtu.be/z3z7iDN04b4
#           ^
# SyntaxError: invalid syntax
